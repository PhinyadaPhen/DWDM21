# %% [markdown]
# <a href="https://colab.research.google.com/github/PhinyadaPhen/DWDM21/blob/main/MiniExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ข้อสอบ
#
# จาก data ```flights.csv``` และ ```airports.csv``` ใน https://drive.google.com/drive/folders/1EFo1_uQgWkRiXjezL0T4YwteYrsqU5MV?usp=sharing
# 0. หารัฐที่มีจำนวนเครื่องบินขาเข้ามากที่สุดและน้อยที่สุด
# 1. หารัฐที่มีจำนวนเครื่องบินขาออกมากที่สุดและน้อยที่สุด
# 2. วาด Histogram แสดงจำนวนเครื่องบินขาออกของแต่ละวันในสัปดาห์
# 3. สายการบินไหนมีเที่ยวบินมากที่สุดและน้อยที่สุด
# 4. สายการบินอะไรมีความล่าช้ามากที่สุดและน้อยที่สุด
# 5. ช่วงเช้าหรือช่วงบ่ายมีเครื่องบินขาเข้ามากกว่ากัน
#
# ให้นักศึกษาทำข้อสอบ 2 ข้อจากที่แสดงข้างบนโดยกรอกรหัสนักศึกษาลงใน function ```gen_exams()``` แล้ว run เพื่อให้ได้ข้อสอบที่นักศึกษาต้องทำ 2 ข้อ (ข้อละ 3 คะแนน)
# และให้นักศึกษาคิดโจทย์เองอีก 1 ข้อ (4 คะแนน)

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AX4XfWiIdews2BrQI8gdTeJskPyTnxFi9t8-t4bl9vptiRu7YIe0BiJSSyk
# Mounted at /content/drive

# %%
import os

# %%
flights = pd.read_csv('/content/drive/MyDrive/DWDM2021_DATA/flights.csv')
flights
# Out:
#          วันในเดือน  วันในสัปดาห์  ... ความล่าช้าขาออก  ความล่าช้าขาเข้า
# 0                19             5  ...              -3                 1
# 1                19             5  ...               0                -8
# 2                19             5  ...              -4               -15
# 3                19             5  ...              28                24
# 4                19             5  ...              -6               -11
# ...             ...           ...  ...             ...               ...
# 2702213          19             6  ...               1                -3
# 2702214          19             6  ...              -2                -3
# 2702215          19             6  ...              18                 9
# 2702216          19             6  ...              10                 7
# 2702217          19             6  ...               0               -13
#
# [2702218 rows x 7 columns]

# %%
airports = pd.read_csv('/content/drive/MyDrive/DWDM2021_DATA/airports.csv')
airports
# Out:
#      รหัสสนามบิน         เมือง รัฐ                          ชื่อสนามบิน
# 0          10165   Adak Island  AK                                 Adak
# 1          10299     Anchorage  AK  Ted Stevens Anchorage International
# 2          10304         Aniak  AK                        Aniak Airport
# 3          10754        Barrow  AK      Wiley Post/Will Rogers Memorial
# 4          10551        Bethel  AK                       Bethel Airport
# ..           ...           ...  ..                                  ...
# 360        11233      Cheyenne  WY  Cheyenne Regional/Jerry Olson Field
# 361        11097          Cody  WY                 Yellowstone Regional
# 362        11865      Gillette  WY             Gillette Campbell County
# 363        12441       Jackson  WY                         Jackson Hole
# 364        14543  Rock Springs  WY       Rock Springs Sweetwater County
#
# [365 rows x 4 columns]

# %%
def gen_exams(ID):
    import math
    a = int(ID[-1])%6
    b = int(ID[-1])%3
    print(f'รหัสนักศึกษา {ID} ทำข้อ {a} และ {b if a != b else 5-b}')

# %% [markdown]
# ตัวอย่างการ run

# %%
gen_exams('623021052-2')
# Out:
# รหัสนักศึกษา 623021052-2 ทำข้อ 2 และ 3

# %% [markdown]
# ## **ข้อสอบที่ต้องทำ**

# %%
Merge_flights_airports = flights.merge(airports,how='left',left_on='รหัสสนามบินต้นทาง',right_on='รหัสสนามบิน') # รวมตารางโดยใช้ Attribute คือ รหัสสนามบินต้นทาง กับ รหัสสนามบิน
Merge_flights_airports
# Out:
#          วันในเดือน  ...                                 ชื่อสนามบิน
# 0                19  ...                  Detroit Metro Wayne County
# 1                19  ...                Salt Lake City International
# 2                19  ...                      Portland International
# 3                19  ...             Lambert-St. Louis International
# 4                19  ...  Cincinnati/Northern Kentucky International
# ...             ...  ...                                         ...
# 2702213          19  ...                       Orlando International
# 2702214          19  ...    Hartsfield-Jackson Atlanta International
# 2702215          19  ...           Albuquerque International Sunport
# 2702216          19  ...    Hartsfield-Jackson Atlanta International
# 2702217          19  ...    Hartsfield-Jackson Atlanta International
#
# [2702218 rows x 11 columns]

# %%
Merge_flights_airports.dropna() # ดูค่า missing
# Out:
#          วันในเดือน  ...                                 ชื่อสนามบิน
# 0                19  ...                  Detroit Metro Wayne County
# 1                19  ...                Salt Lake City International
# 2                19  ...                      Portland International
# 3                19  ...             Lambert-St. Louis International
# 4                19  ...  Cincinnati/Northern Kentucky International
# ...             ...  ...                                         ...
# 2702213          19  ...                       Orlando International
# 2702214          19  ...    Hartsfield-Jackson Atlanta International
# 2702215          19  ...           Albuquerque International Sunport
# 2702216          19  ...    Hartsfield-Jackson Atlanta International
# 2702217          19  ...    Hartsfield-Jackson Atlanta International
#
# [2702218 rows x 11 columns]

# %% [markdown]
# ### ข้อ 2 วาด Histogram แสดงจำนวนเครื่องบินขาออกของแต่ละวันในสัปดาห์

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # import matplotlib เพื่อเรียกใช้งานฟังก์ชั่นสำหรับพล็อตฮิสโทแกรม

# %%
HisFlights = Merge_flights_airports.merge(airports,how='left',left_on='รหัสสนามบินต้นทาง',right_on='รหัสสนามบิน')
HisFlights
# Out:
#          วันในเดือน  ...                               ชื่อสนามบิน_y
# 0                19  ...                  Detroit Metro Wayne County
# 1                19  ...                Salt Lake City International
# 2                19  ...                      Portland International
# 3                19  ...             Lambert-St. Louis International
# 4                19  ...  Cincinnati/Northern Kentucky International
# ...             ...  ...                                         ...
# 2702213          19  ...                       Orlando International
# 2702214          19  ...    Hartsfield-Jackson Atlanta International
# 2702215          19  ...           Albuquerque International Sunport
# 2702216          19  ...    Hartsfield-Jackson Atlanta International
# 2702217          19  ...    Hartsfield-Jackson Atlanta International
#
# [2702218 rows x 15 columns]

# %%
week = HisFlights.groupby('วันในสัปดาห์')[['รหัสสนามบินต้นทาง']].count()
week
# Out:
#               รหัสสนามบินต้นทาง
# วันในสัปดาห์
# 1                        407837
# 2                        397594
# 3                        403072
# 4                        406563
# 5                        396387
# 6                        318537
# 7                        372228

# %%
week.reset_index(inplace=True)
week
# Out:
#    วันในสัปดาห์  รหัสสนามบินต้นทาง
# 0             1             407837
# 1             2             397594
# 2             3             403072
# 3             4             406563
# 4             5             396387
# 5             6             318537
# 6             7             372228

# %%
plt.bar(np.arange(len(week.iloc[:,1])), week.iloc[:,1])
plt.xlabel('number Day')
plt.ylabel('count of out')
plt.title('count of out for each number day')
plt.xticks(np.arange(len(week.iloc[:,0]))+0.5, week.iloc[:,0])
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### ข้อ 3 สายการบินไหนมีเที่ยวบินมากที่สุดและน้อยที่สุด

# %%
Merge_flights_airports.groupby('สายการบิน').count() # นับจํานวนรายการในคอลัมน์
# Out:
#            วันในเดือน  วันในสัปดาห์  ...     รัฐ  ชื่อสนามบิน
# สายการบิน                            ...
# 9E              80031         80031  ...   80031        80031
# AA             289855        289855  ...  289855       289855
# AS              68555         68555  ...   68555        68555
# B6             121906        121906  ...  121906       121906
# DL             381657        381657  ...  381657       381657
# EV             157928        157928  ...  157928       157928
# F9              35738         35738  ...   35738        35738
# FL              92702         92702  ...   92702        92702
# HA              17432         17432  ...   17432        17432
# MQ             113212        113212  ...  113212       113212
# OO             160164        160164  ...  160164       160164
# UA             286418        286418  ...  286418       286418
# US             233321        233321  ...  233321       233321
# ...

# %%
FlightsNew = Merge_flights_airports.groupby('สายการบิน').count().sort_values(by=['วันในเดือน'],ascending=False)
FlightsNew.iloc[:,0:1] # ตัดตารางเพื่อให้ดูข้อมูลง่ายขึ้น
# Out:
#            วันในเดือน
# สายการบิน
# WN             575739
# DL             381657
# AA             289855
# UA             286418
# US             233321
# OO             160164
# EV             157928
# B6             121906
# MQ             113212
# FL              92702
# 9E              80031
# AS              68555
# YV              52821
# F9              35738
# VX              34739
# HA              17432

# %%
MaxFlight = FlightsNew.iloc[:1,:1] # สายการบินที่มีเที่ยวบินมากที่สุด
MaxFlight
# Out:
#            วันในเดือน
# สายการบิน
# WN             575739

# %% [markdown]
# ดังนั้น สายการบินที่มีเที่ยวบินมากที่สุด คือ สายการบิน WN

# %%
MinFlight = FlightsNew.iloc[15:,:1] # สายการบินที่มีเที่ยวบินน้อยที่สุด
MinFlight
# Out:
#            วันในเดือน
# สายการบิน
# HA              17432

# %% [markdown]
# ดังนั้น สายการบินที่มีเที่ยวบินน้อยที่สุด คือ สาบการบิน HA

# %% [markdown]
# ### โจทย์คิดเอง เมืองใดมีจำนวนเครื่องบินขาออกมากที่สุด

# %%
Merge_flights_airports.groupby('เมือง').count() # นับจำนวนรายการในคอลัมน์
# Out:
#                             วันในเดือน  วันในสัปดาห์  ...     รัฐ  ชื่อสนามบิน
# เมือง                                                 ...
# Albuquerque                      17542         17542  ...   17542        17542
# Anchorage                         7700          7700  ...    7700         7700
# Atlanta                         148563        148563  ...  148563       148563
# Austin                           26982         26982  ...   26982        26982
# Baltimore                        51761         51761  ...   51761        51761
# ...                                ...           ...  ...     ...          ...
# St. Louis                        33061         33061  ...   33061        33061
# Tampa                            35149         35149  ...   35149        35149
# Tucson                           10990         10990  ...   10990        10990
# Washington                       80536         80536  ...   80536        80536
# ...

# %%
City = Merge_flights_airports.groupby('เมือง').count().sort_values(by=['ความล่าช้าขาออก'],ascending=False)
City.iloc[:,5:6] # ตัดตารางที่ไม่ใช้ออกเพื่อให้ดูขอมูลง่ายขึ้น
# Out:
#                             ความล่าช้าขาออก
# เมือง
# Chicago                              176939
# Atlanta                              148563
# New York                             118026
# Los Angeles                          117714
# Dallas/Fort Worth                    104270
# ...                                     ...
# West Palm Beach/Palm Beach            10091
# Norfolk                               10006
# Providence                             9313
# Long Beach                             8166
# Anchorage                              7700
#
# [66 rows x 1 columns]

# %%
MaxCity = City.iloc[:1,:1] # สายการบินที่มีเที่ยวบินมากที่สุด
MaxCity
# Out:
#          วันในเดือน
# เมือง
# Chicago      176939

# %% [markdown]
# สรุป เมืองที่มีสายการบินขาออกมากที่สุดคือ เมือง Chicago

# %% [markdown]
# **จบ**
